# %%
import pandas as pd
import numpy as np

# %%
# values count (series and dataframe)
a = pd.Series([1,1,2,3,4,5,6,4,2]).value_counts()
a
# Out:
# 1    2
# 2    2
# 4    2
# 3    1
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
mark = pd.DataFrame([[67, 45, 24], [54, 78, 45], [57, 36,56], [23, 78, 45],[23,78,45]], columns=["iq","mark","package"]).value_counts()
mark
# Out:
# iq  mark  package
# 23  78    45         2
# 54  78    45         1
# 57  36    56         1
# 67  45    24         1
# Name: count, dtype: int64

# %%
df = pd.read_csv("Data_Sets/movies.csv")
df.head(5)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
df.sort_values(['title_x'],ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# no nan values hoy to te by-default last ma aavse

# pan tene uper pan lavi shakay

# %%
b = {"maths": 89, "science": 67, "english": 45, "hindi": 34}
b
b_series = pd.Series(b)
b_series
# Out:
# maths      89
# science    67
# english    45
# hindi      34
# dtype: int64

# %%
b_series.sort_index()
# Out:
# english    45
# hindi      34
# maths      89
# science    67
# dtype: int64

# %%
# set index (data frame)

ind = pd.DataFrame({'name':['sakshi','isha','neha','rachi','princi','pinal','akshali'],'marks':[90,78,56,78,43,56,78],'pakage':[2,3,6,7,1,8,6]})
ind
# Out:
#       name  marks  pakage
# 0   sakshi     90       2
# 1     isha     78       3
# 2     neha     56       6
# 3    rachi     78       7
# 4   princi     43       1
# 5    pinal     56       8
# 6  akshali     78       6

# %%
ind.set_index('name',inplace=True)
ind
# Out:
#          marks  pakage
# name
# sakshi      90       2
# isha        78       3
# neha        56       6
# rachi       78       7
# princi      43       1
# pinal       56       8
# akshali     78       6

# %%
# reset index (data frame , series)

ind.reset_index(inplace=True)

# %%
ind
# Out:
#       name  marks  pakage
# 0   sakshi     90       2
# 1     isha     78       3
# 2     neha     56       6
# 3    rachi     78       7
# 4   princi     43       1
# 5    pinal     56       8
# 6  akshali     78       6

# %%
ind.set_index("marks")
# Out:
#           name  pakage
# marks
# 90      sakshi       2
# 78        isha       3
# 56        neha       6
# 78       rachi       7
# 43      princi       1
# 56       pinal       8
# 78     akshali       6

# %%
# remname index (data frame)

movie = pd.read_csv("Data_Sets/movies.csv")

movie.set_index("title_x", inplace=True)
movie
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.rename(columns={'imdb_id':'imdb','poster_path':'URL'},inplace=True)

# %%
movie
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                     URL  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.rename(index={"Uri: The Surgical Strike": "ABC"})
# Out:
#                                             imdb  \
# title_x
# ABC                                    tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                     URL  \
# title_x
# ABC                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# unique

temp = pd.Series([1,2,3,4,1,2,2,4,5,6,np.nan,np.nan])
temp.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6., nan])

# %%
temp.nunique()
# Out:
# 6

# %%
len(temp.unique())
# Out:
# 7

# %%
temp.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# dtype: bool

# %%
temp.notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# dtype: bool

# %%
temp.hasnans  # attribute
# Out:
# True

# %% [markdown]
# ### dropna

# %%
temp.dropna(how='any')
temp.dropna(how='all')

temp.dropna(subset=['name','matk'])

# %% [markdown]
# ### filna

# %%
temp.fillna('unknown')
temp.fillna(method='ffill')  #  forward fill next je hoy te print kari dey
temp.fillna(method='bfill')  #  backwork fill  pachal je hoy te print kari dey

# %% [markdown]
# ### drop dublicates
